# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/uncover/hackathon_file_readme.txt
# /kaggle/input/uncover/geotab/border-wait-times-at-us-canada-border.csv
# /kaggle/input/uncover/geotab/airport-traffic-analysis.csv
# /kaggle/input/uncover/nextstrain/covid-19-genetic-phylogeny.csv
# /kaggle/input/uncover/hifld/hifld/us-ports-of-entry.csv
# /kaggle/input/uncover/hifld/hifld/public-health-departments.csv
# /kaggle/input/uncover/hifld/hifld/urgent-care-facilities.csv
# /kaggle/input/uncover/hifld/hifld/aircraft-landing-facilities.csv
# /kaggle/input/uncover/hifld/hifld/nursing-homes.csv
# /kaggle/input/uncover/hifld/hifld/local-emergency-operations-centers-eoc.csv
# /kaggle/input/uncover/hifld/hifld/hospitals.csv
# /kaggle/input/uncover/covid_tracker_canada/covid-19-tracker-canada.csv
# /kaggle/input/uncover/USAFacts/confirmed-covid-19-deaths-in-us-by-state-and-county.csv
# /kaggle/input/uncover/USAFacts/confirmed-covid-19-cases-in-us-by-state-and-county.csv
# ...

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
canadaDataFile='/kaggle/input/uncover/canadian_outbreak_tracker/canada-cumulative-case-counts-by-province.csv'
canadaData=pd.read_csv(canadaDataFile,parse_dates=True)

# %%
canadaData.tail(5)
# Out:
#       objectid           date    bc    ab   sk   mb    on    qc   nb   ns  pe  \
# 4420        49  1585742400000  1066   871  193  127  2392  4611   81  173  21
# 4421        50  1585828800000  1121   968  206  167  2793  5518   92  193  21
# 4422        51  1585945560000  1174  1075  220  182  3255  6101   95  207  22
# 4423        52  1586029080000  1203  1181  231  194  3630  6997   98  236  22
# 4424        53  1586116440000  1203  1250  249  203  4038  7944  101  262  22
#
#        nl  repatriated  canadatotal  canadadaily  nt nu  yt  \
# 4420  175           13         9731         1140   2  f   6
# 4421  183           13        11283         1552   2  f   6
# 4422  195           13        12549         1266   4  f   6
# 4423  203           13        14018         1469   4  f   6
# 4424  217           13        15512         1494   4  f   6
#
#              retrieved_at
# 4420  2020-04-06 04:15:00
# 4421  2020-04-06 04:15:00
# 4422  2020-04-06 04:15:00
# ...

# %% [markdown]
# # Trends of increasing cases in Candian Provinces

# %%
plt.figure(figsize=(20,8))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')
plt.title("Projection: Covid Cases in Manitoba")
sns.barplot(x=canadaData['objectid'],y=canadaData['mb'])

# %%
plt.figure(figsize=(20,8))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')
plt.title("Projection: Covid Cases in Saskatchewan")

sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])

# %%
plt.figure(figsize=(20,18))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')
plt.title("Projection: Covid Cases in Ontario")
sns.barplot(x=canadaData['objectid'],y=canadaData['on'])
#sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])

# %%
plt.figure(figsize=(20,25))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')
plt.title("Projection: Covid Cases in Quebec")
sns.barplot(x=canadaData['objectid'],y=canadaData['qc'])
#sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])

# %%
plt.figure(figsize=(20,25))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')
plt.title("Projection: Covid Cases in British Columbia")
sns.barplot(x=canadaData['objectid'],y=canadaData['bc'])
#sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])

# %%
plt.figure(figsize=(20,25))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')
plt.title("Projection: Covid Cases in Alberta")
sns.barplot(x=canadaData['objectid'],y=canadaData['ab'])
#sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])
