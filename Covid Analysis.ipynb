# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %%
canadaDataFile='/kaggle/input/uncover/canadian_outbreak_tracker/canada-cumulative-case-counts-by-province.csv'
canadaData=pd.read_csv(canadaDataFile,parse_dates=True)

# %%
canadaData.head(5)

# %%
plt.figure(figsize=(20,8))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')

sns.barplot(x=canadaData['objectid'],y=canadaData['mb'])

# %%
plt.figure(figsize=(20,8))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')


sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])

# %%
plt.figure(figsize=(20,18))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')

sns.barplot(x=canadaData['objectid'],y=canadaData['on'])
#sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])

# %%
plt.figure(figsize=(20,25))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')

sns.barplot(x=canadaData['objectid'],y=canadaData['qc'])
#sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])

# %%
plt.figure(figsize=(20,25))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')

sns.barplot(x=canadaData['objectid'],y=canadaData['bc'])
#sns.barplot(x=canadaData['objectid'],y=canadaData['sk'])

# %%
canadaDataNew=pd.read_csv(canadaDataFile,index_col='objectid',parse_dates=True)

# %%
canadaDataNew.head()

# %%
plt.figure(figsize=(20,8))
sns.set_style('white')
#sns.lineplot(data=canadaData['mb'],label='mb')
#sns.lineplot(data=canadaData['sk'],label='sk')

#sns.kdeplot(data=canadaDataNew['mb'],shade=True)
sns.distplot(a=canadaDataNew['mb'],kde=False)
#sns.barplot(x=canadaDataNew.index,y=canadaDataNew['mb'])

# %%
cumulativeFile='/kaggle/input/uncover/canadian_outbreak_tracker/canada-cumulative-case-counts.csv'
cumulativeProvinceFile='/kaggle/input/uncover/canadian_outbreak_tracker/canada-cumulative-case-counts-by-province.csv'
provinceFile='/kaggle/input/uncover/canadian_outbreak_tracker/canada-enriched-population-case-data-by-province.csv'
hybridRegionalFile='/kaggle/input/uncover/canadian_outbreak_tracker/canada-cumulative-case-count-by-new-hybrid-regional-health-boundaries.csv'
cumulativeData=pd.read_csv(cumulativeFile)
cumulativeProvinceData=pd.read_csv(cumulativeProvinceFile)
provinceData=pd.read_csv(provinceFile)
hybridRegionalData=pd.read_csv(hybridRegionalFile)

# %%
cumulativeData.tail()

# %%
cumulativeProvinceData.head()

# %%
provinceData.head()

# %%
hybridRegionalData.head()
